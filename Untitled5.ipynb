# %% [markdown]
# <a href="https://colab.research.google.com/github/ALSABITHHABEEB/INTRODUCTION-TO-SQL/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello world')
# Out:
# Hello world

# %%
print(123)
# Out:
# 123

# %%
x=10
print(x)
# Out:
# 10

# %%
x=10.5
print(x)
# Out:
# 10.5

# %%
x="Hello world"
print(x)
# Out:
# Hello world

# %%
x=5
y=10
print(x+y)
# Out:
# 15

# %%
x=5
y="hello"
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-32576059af37> in <module>
#       1 x=5
#       2 y="hello"
# ----> 3 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x="Hello"
print(x)
# Out:
# Hello

# %%
x="ABC"
print(type(x))
# Out:
# <class 'str'>

# %%
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
x="10"
print(type(x))
# Out:
# <class 'str'>

# %%
x=10
y=20
z=x+y
print(type(z))
# Out:
# <class 'int'>

# %%
x='10'
y='20'
z=x+y
print(type(z))
# Out:
# <class 'str'>

# %%
a=3.564
print("a=",a)
# Out:
# a= 3.564

# %%
x=5
y=10
print('x is {} and y is {}'.format(x,y))
# Out:
# x is 5 and y is 10

# %%
num=input('enter a number:')
print('you entered:',num)
# Out:
# enter a number:7
# you entered: 7

# %%
num= input('A =')
print('type=', type(num))
# Out:
# A =kjhgfldjhc
# type= <class 'str'>

# %%
name= input("enter your name?")
print("nice to meet you"+name+"!")
# Out:
# enter your name?alsabith
# nice to meet youalsabith!

# %%
x,y=2,10
print(x,y)
# Out:
# 2 10

# %%
x,y,z,t= "alsabith",19,"ernakulam",9058
print(x,y,z,t)
# Out:
# alsabith 19 ernakulam 9058

# %%
x=int(input())
y=int(input())
x>y
# Out:
# 6
# 7
# False

# %%
x=bytearray(12345)
print(x)
print(type(x))
# Out:
# bytearray(b'\x
# ...

# %%
x=10.5
print(x)
type(x)
y=int(x)
print(y)
print(type(y))
# Out:
# 10.5
# 10
# <class 'int'>

# %%
x_y=10
y_x=20
x_y+y_x
# Out:
# 30

# %%
_x=10
_y=20
_x+_y
# Out:
# 30

# %%
xY=10
yX=20
xY+yX
# Out:
# 30

# %%
ABC1="hello world"
1ABC="hello world"
# Out:
#   File "<ipython-input-46-45103e839499>", line 2
#     1ABC="hello world"
#      ^
# SyntaxError: invalid syntax

# %%
ABC="hello world"
abc="hello world"

# %%
x=10
x+=3
x
# Out:
# 13

# %%
  x=10
  x%=4
  x
# Out:
# 2

# %%
x,y=10,25
print(x!=y)
print(x>=y)
# Out:
# True
# False

# %%
x=2
y=10
print(x+y)
print(x-y)
print(x/y)
print(x*y)
# Out:
# 12
# -8
# 0.2
# 20

# %%
print(11%5)
print(11//5)
# Out:
# 1
# 2
